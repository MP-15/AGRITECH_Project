# %% [markdown]
# <a href="https://colab.research.google.com/github/MP-15/AGRITECH_Project/blob/main/District_Amritsar_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


# reading the database
data = pd.read_csv("/content/drive/MyDrive/Amritsar - Sheet1.csv")

# printing the top 10 rows
display(data.head(10))
# Out:
#   State Name District Name Market Name Variety    Group  Arrivals (Tonnes)  \
# 0     Punjab      Amritsar      Attari   Other  Cereals               1190
# 1     Punjab      Amritsar      Attari   Other  Cereals                560
# 2     Punjab      Amritsar      Attari   Other  Cereals                 28
# 3     Punjab      Amritsar      Attari   Other  Cereals                 52
# 4     Punjab      Amritsar      Attari   Other  Cereals                220
# 5     Punjab      Amritsar      Attari   Other  Cereals                675
# 6     Punjab      Amritsar      Attari   Other  Cereals                112
# 7     Punjab      Amritsar      Attari   Other  Cereals                140
# 8     Punjab      Amritsar      Attari   Other  Cereals               1135
# 9     Punjab      Amritsar      Attari   Other  Cereals               1310
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                     2125                     2125
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.shape
# Out:
# (320, 10)

# %%
df1['A'].plot.hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-28a95f57af4b> in <cell line: 1>()
# ----> 1 df1['A'].plot.hist(bins=50)
#
# NameError: name 'df1' is not defined
